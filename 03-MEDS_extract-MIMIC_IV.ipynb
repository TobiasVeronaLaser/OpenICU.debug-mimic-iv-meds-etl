# %%
# %%bash
# source .venv/bin/activate
# rm -rf output/MEDS_cohort
# rm -rf output/pre_MEDS
# export HYDRA_FULL_ERROR=1

# %%
# !MEDS_extract-MIMIC_IV root_output_dir=output raw_input_dir=output/raw_input pre_MEDS_dir=output/pre_MEDS MEDS_cohort_dir=output/MEDS_cohort do_demo=True do_download=False do_overwrite=True
