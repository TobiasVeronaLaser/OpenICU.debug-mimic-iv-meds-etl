# %%
# !rm -rf ./../output
# !mkdir ./../output

# %%
# !/workspaces/.venv/bin/python -m ensurepip --upgrade

# %%
# !/workspaces/.venv/bin/python -m pip install --upgrade pip

# %%
# !/workspaces/.venv/bin/python -m pip install MIMIC_IV_MEDS

# %%
# !/workspaces/.venv/bin/python -m pip freeze

# %%
import os
os.environ["HYDRA_FULL_ERROR"] = "1"

# %%
# !MEDS_extract-MIMIC_IV root_output_dir=output do_demo=True
