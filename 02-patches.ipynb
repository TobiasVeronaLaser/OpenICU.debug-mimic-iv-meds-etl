# %%
from patches import (
    build_config,
    validate_paths,
    print_config,
    apply_patches,
    print_result,
)
from pathlib import Path

# %%
config = build_config(
    dry_run=False,
    venv_site_packages=Path("/home/q039tl/projects/OpenICU.debug-mimic-iv-meds-etl/.venv/lib/python3.12/site-packages"),
)
validate_paths(config)
print_config(config)
result = apply_patches(config)
print_result(result)
